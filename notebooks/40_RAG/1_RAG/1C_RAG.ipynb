# %% [markdown]
# # Components RAG Chain
#
# - Context: vectordb
# - Prompt: question
# - LLM: model to run the query with
# - OutputParser: output format
#
# ```python
# rag_chain = (
#     {"context": retriever | format_docs, "question": RunnablePassthrough()}
#     | prompt
#     | llm
#     | StrOutputParser()
# )
# ```

# %% [markdown]
# ## Vector DB

# %% [markdown]
# ### Instantiate vectordb

# %%
from modules.vectordb.bocyl import get_vectordb_bocyl
vectordb = get_vectordb_bocyl(persist_directory=True)

vectordb

# %% [markdown]
# ### [X] Insert documents
#
# If you want to insert new documents, you can add the urls to the list below.

# %%
urls = [
    'https://bocyl.jcyl.es/boletines/2025/04/21/xml/BOCYL-D-21042025-1.xml',
    'https://bocyl.jcyl.es/boletines/2025/04/14/xml/BOCYL-D-14042025-56.xml',
    'https://bocyl.jcyl.es/boletines/2025/04/11/xml/BOCYL-D-11042025-15.xml',
    'https://bocyl.jcyl.es/boletines/2025/04/07/xml/BOCYL-D-07042025-29.xml',
    'https://bocyl.jcyl.es/boletines/2025/04/02/xml/BOCYL-D-02042025-23.xml',
    'https://bocyl.jcyl.es/boletines/2025/04/02/xml/BOCYL-D-02042025-45.xml',
    'https://bocyl.jcyl.es/boletines/2025/04/02/xml/BOCYL-D-02042025-48.xml',
    'https://bocyl.jcyl.es/boletines/2025/03/21/xml/BOCYL-D-21032025-1.xml',
    'https://bocyl.jcyl.es/boletines/2025/03/21/xml/BOCYL-D-21032025-2.xml',
    'https://bocyl.jcyl.es/boletines/2025/03/21/xml/BOCYL-D-21032025-9.xml',
    'https://bocyl.jcyl.es/boletines/2025/03/21/xml/BOCYL-D-21032025-21.xml',
    'https://bocyl.jcyl.es/boletines/2025/03/21/xml/BOCYL-D-21032025-22.xml',
    'https://bocyl.jcyl.es/boletines/2025/03/21/xml/BOCYL-D-21032025-23.xml',
    'https://bocyl.jcyl.es/boletines/2025/03/21/xml/BOCYL-D-21032025-24.xml',
    'https://bocyl.jcyl.es/boletines/2025/03/21/xml/BOCYL-D-21032025-25.xml',
    'https://bocyl.jcyl.es/boletines/2025/03/21/xml/BOCYL-D-21032025-26.xml',
    'https://bocyl.jcyl.es/boletines/2025/03/07/xml/BOCYL-D-07032025-16.xml',
    'https://bocyl.jcyl.es/boletines/2025/03/07/xml/BOCYL-D-07032025-17.xml',
    'https://bocyl.jcyl.es/boletines/2025/02/26/xml/BOCYL-D-26022025-18.xml',
    'https://bocyl.jcyl.es/boletines/2025/02/10/xml/BOCYL-D-10022025-2.xml',
]

# %%
from pathlib import Path
folder_documents = Path("/workspace/data/documents/BOCYL")

# %%
from modules.preprocessing import BOCYLMarkdownExporter
exporter = BOCYLMarkdownExporter(folder_documents)

# %%
paths = []

for url in urls:
    exporter.export(url)
    filename = url.split('/')[-1].split('.')[0]
    path = folder_documents / f"{filename}.md"
    paths.append(path)

paths
# Out:
# [PosixPath('/workspace/data/documents/BOCYL/BOCYL-D-21042025-1.md'),
#  PosixPath('/workspace/data/documents/BOCYL/BOCYL-D-14042025-56.md'),
#  PosixPath('/workspace/data/documents/BOCYL/BOCYL-D-11042025-15.md'),
#  PosixPath('/workspace/data/documents/BOCYL/BOCYL-D-07042025-29.md'),
#  PosixPath('/workspace/data/documents/BOCYL/BOCYL-D-02042025-23.md'),
#  PosixPath('/workspace/data/documents/BOCYL/BOCYL-D-02042025-45.md'),
#  PosixPath('/workspace/data/documents/BOCYL/BOCYL-D-02042025-48.md'),
#  PosixPath('/workspace/data/documents/BOCYL/BOCYL-D-21032025-1.md'),
#  PosixPath('/workspace/data/documents/BOCYL/BOCYL-D-21032025-2.md'),
#  PosixPath('/workspace/data/documents/BOCYL/BOCYL-D-21032025-9.md'),
#  PosixPath('/workspace/data/documents/BOCYL/BOCYL-D-21032025-21.md'),
#  PosixPath('/workspace/data/documents/BOCYL/BOCYL-D-21032025-22.md'),
#  PosixPath('/workspace/data/documents/BOCYL/BOCYL-D-21032025-23.md'),
#  PosixPath('/workspace/data/documents/BOCYL/BOCYL-D-21032025-24.md'),
#  PosixPath('/workspace/data/documents/BOCYL/BOCYL-D-21032025-25.md'),
#  PosixPath('/workspace/data/documents/BOCYL/BOCYL-D-21032025-26.md'),
#  PosixPath('/workspace/data/documents/BOCYL/BOCYL-D-07032025-16.md'),
#  PosixPath('/workspace/data/documents/BOCYL/BOCYL-D-07032025-17.md'),
#  PosixPath('/workspace/data/documents/BOCYL/BOCYL-D-26022025-18.md'),
#  PosixPath('/workspace/data/documents/BOCYL/BOCYL-D-10022025-2.md')]

# %%
vectordb.upsert_documents(paths)
# Out:
# Document BOCYL-D-21042025-1 not found
# Added BOCYL-D-21042025-1 with 4 sections and metadata: {'doc_id': 'BOCYL-D-21042025-1', 'date': '2025-04-21', 'doc_number': 1, 'source': 'BOCYL', 'type': 'official_document', 'area': 'AGRARIA', 'consejeria': 'AGRICULTURA Y PESCA', 'title': 'ORDEN SAN/378/2025, de 4 de abril, por la que se resuelve convocatoria pública para cubrir, mediante el sistema de libre designación, el puesto de trabajo que se cita.'}
# Document BOCYL-D-14042025-56 not found
# Added BOCYL-D-14042025-56 with 11 sections and metadata: {'doc_id': 'BOCYL-D-14042025-56', 'date': '2025-04-14', 'doc_number': 56, 'source': 'BOCYL', 'type': 'official_document', 'area': 'AGRARIA', 'consejeria': 'AGRICULTURA Y PESCA', 'title': 'RESOLUCIÓN de 7 de abril de 2025, del Servicio Territorial de Agricultura, Ganadería y Desarrollo Rural de Zamora, por la que se convoca asamblea única para la elección de los miembros que van a formar parte del grupo auxiliar de trabajo y de la comisión local, en relación con la concentración parcelaria de la zona de Benegiles II (Zamora).'}
# Document BOCYL-D-11042025-15 not found
# Added BOCYL-D-11042025-15 with 2 sections and metadata: {'doc_id': 'BOCYL-D-11042025-15', 'date': '2025-04-11', 'doc_number': 15, 'source': 'BOCYL', 'type': 'official_document', 'area': 'AGRARIA', 'consejeria': 'AGRICULTURA Y PESCA', 'title': 'EXTRACTO de la Orden de 8 de abril de 2025, de la Consejería de Agricultura, Ganadería y Desarrollo Rural, por la que se convocan las ayudas a la cosecha en verde de viñedos en la Comunidad de Castilla y León para la vendimia 2025.'}
# Document BOCYL-D-07042025-29 not found
# Added BOCYL-D-07042025-29 with 11 sections and metadata: {'doc_id': 'BOCYL-D-07042025-29', 'date': '2025-04-07', 'doc_number': 29, 'source': 'BOCYL', 'type': 'official_document', 'area': 'AGRARIA', 'consejeria': 'AGRICULTURA Y PESCA', 'title': 'RESOLUCIÓN de 31 de marzo de 2025, del Servicio Territorial de Agricultura, Ganadería y Desarrollo Rural de Zamora, por la que se convoca asamblea única para la elección de los miembros que van a formar parte de los grupos auxiliares de trabajo y de la comisión local en relación con la concentración parcelaria de la zona de San Román de los Infantes (Zamora).'}
# Document BOCYL-D-02042025-23 not found
# Added BOCYL-D-02042025-23 with 476 sections and metadata: {'doc_id': 'BOCYL-D-02042025-23', 'date': '2025-04-02', 'doc_number': 23, 'source': 'BOCYL', 'type': 'official_document', 'area': 'AGRARIA', 'consejeria': 'AGRICULTURA Y PESCA', 'title': 'RESOLUCIÓN de 19 de marzo de 2025, de la Dirección General de Política Agraria Comunitaria, por la que se establece la clasificación de los criterios de evaluación de gravedad, alcance y persistencia, y el cálculo de las reducciones a los efectos de aplicar la condicionalidad reforzada y social de las ayudas de la Política Agrícola Común, en el año 2024.'}
# Document BOCYL-D-02042025-45 not found
# Added BOCYL-D-02042025-45 with 5 sections and metadata: {'doc_id': 'BOCYL-D-02042025-45', 'date': '2025-04-02', 'doc_number': 45, 'source': 'BOCYL', 'type': 'official_document', 'area': 'AGRARIA', 'consejeria': 'AGRICULTURA Y PESCA', 'title': 'RESOLUCIÓN de 18 de marzo de 2025, de la Dirección General de Producción Agrícola y Ganadera, por la que se extingue el reconocimiento como Agrupación de Defensa Sanitaria de Ganado Porcino a la denominada «La Ribera» en la provincia de Burgos.'}
# Document BOCYL-D-02042025-48 not found
# Added BOCYL-D-02042025-48 with 6 sections and metadata: {'doc_id': 'BOCYL-D-02042025-48', 'date': '2025-04-02', 'doc_number': 48, 'source': 'BOCYL', 'type': 'official_document', 'area': 'AGRARIA', 'consejeria': 'AGRICULTURA Y PESCA', 'title': 'RESOLUCIÓN de 24 de marzo de 2025, del Servicio Territorial de Agricultura, Ganadería y Desarrollo Rural de Segovia, relativa a la convocatoria de asamblea única para la elección de los miembros que van a formar parte de la Comisión Local, en relación con la concentración parcelaria de la zona de Aguilafuente (Segovia).'}
# Document BOCYL-D-21032025-1 not found
# Added BOCYL-D-21032025-1 with 3 sections and metadata: {'doc_id': 'BOCYL-D-21032025-1', 'date': '2025-03-21', 'doc_number': 1, 'source': 'BOCYL', 'type': 'official_document', 'area': 'AGRARIA', 'consejeria': 'AGRICULTURA Y PESCA', 'title': 'ORDEN AGR/264/2025, de 12 de marzo, por la que se resuelve convocatoria pública para cubrir, mediante el sistema de libre designación, el puesto de trabajo que se cita.'}
# Document BOCYL-D-21032025-2 not found
# Added BOCYL-D-21032025-2 with 3 sections and metadata: {'doc_id': 'BOCYL-D-21032025-2', 'date': '2025-03-21', 'doc_number': 2, 'source': 'BOCYL', 'type': 'official_document', 'area': 'AGRARIA', 'consejeria': 'AGRICULTURA Y PESCA', 'title': 'RESOLUCIÓN de 13 de marzo de 2025, de la Secretaria General de la Consejería de Agricultura, Ganadería y Desarrollo Rural, por la que se aprueba y publica la relación definitiva de candidatos de la bolsa de empleo temporal del Cuerpo de Ayudantes Facultativos (Inspectores de Campo) de la Administración de la Comunidad de Castilla y León, convocada por Orden PRE/556/2024, de 7 de junio.'}
# Document BOCYL-D-21032025-9 not found
# Added BOCYL-D-21032025-9 with 3 sections and metadata: {'doc_id': 'BOCYL-D-21032025-9', 'date': '2025-03-21', 'doc_number': 9, 'source': 'BOCYL', 'type': 'official_document', 'area': 'AGRARIA', 'consejeria': 'AGRICULTURA Y PESCA', 'title': 'ORDEN AGR/265/2025, de 12 de marzo, por la que se anuncia convocatoria pública para cubrir, mediante el sistema de libre designación, el puesto de trabajo que se cita.'}
# Document BOCYL-D-21032025-21 not found
# Added BOCYL-D-21032025-21 with 5 sections and metadata: {'doc_id': 'BOCYL-D-21032025-21', 'date': '2025-03-21', 'doc_number': 21, 'source': 'BOCYL', 'type': 'official_document', 'area': 'AGRARIA', 'consejeria': 'AGRICULTURA Y PESCA', 'title': 'ORDEN AGR/263/2025, de 11 de marzo, por la que se resuelve la aprobación del plan de obras de la infraestructura rural de la zona regable del Canal de San José-Sector I (Zamora).'}
# Document BOCYL-D-21032025-22 not found
# Added BOCYL-D-21032025-22 with 4 sections and metadata: {'doc_id': 'BOCYL-D-21032025-22', 'date': '2025-03-21', 'doc_number': 22, 'source': 'BOCYL', 'type': 'official_document', 'area': 'AGRARIA', 'consejeria': 'AGRICULTURA Y PESCA', 'title': 'RESOLUCIÓN de 6 de marzo de 2025, de la Dirección General de Producción Agrícola y Ganadera, por la que se extingue el reconocimiento como Agrupación de Defensa Sanitaria de ganado vacuno de aptitud extensiva de carne a la denominada «Valles de Gredos», en la provincia de Ávila.'}
# Document BOCYL-D-21032025-23 not found
# Added BOCYL-D-21032025-23 with 4 sections and metadata: {'doc_id': 'BOCYL-D-21032025-23', 'date': '2025-03-21', 'doc_number': 23, 'source': 'BOCYL', 'type': 'official_document', 'area': 'AGRARIA', 'consejeria': 'AGRICULTURA Y PESCA', 'title': 'RESOLUCIÓN de 6 de marzo de 2025 , de la Dirección General de Producción Agrícola y Ganadera, por la que se extingue el reconocimiento como Agrupación de Defensa Sanitaria de ganado vacuno de aptitud láctea a la denominada «Mayorga-Villalón», en la provincia de Valladolid.'}
# Document BOCYL-D-21032025-24 not found
# Added BOCYL-D-21032025-24 with 4 sections and metadata: {'doc_id': 'BOCYL-D-21032025-24', 'date': '2025-03-21', 'doc_number': 24, 'source': 'BOCYL', 'type': 'official_document', 'area': 'AGRARIA', 'consejeria': 'AGRICULTURA Y PESCA', 'title': 'RESOLUCIÓN de 6 de marzo de 2025, de la Dirección General de Producción Agrícola y Ganadera, por la que se extingue el reconocimiento como Agrupación de Defensa Sanitaria de ganado ovino y caprino a la denominada «Campos de Medina-Asaja», en la provincia de Valladolid.'}
# Document BOCYL-D-21032025-25 not found
# Added BOCYL-D-21032025-25 with 4 sections and metadata: {'doc_id': 'BOCYL-D-21032025-25', 'date': '2025-03-21', 'doc_number': 25, 'source': 'BOCYL', 'type': 'official_document', 'area': 'AGRARIA', 'consejeria': 'AGRICULTURA Y PESCA', 'title': 'RESOLUCIÓN de 6 de marzo de 2025, de la Dirección General de Producción Agrícola y Ganadera, por la que se extingue el reconocimiento como Agrupación de Defensa Sanitaria de ganado vacuno de aptitud láctea a la denominada «Pesadero La Corona», en la provincia de Zamora.'}
# Document BOCYL-D-21032025-26 not found
# Added BOCYL-D-21032025-26 with 231 sections and metadata: {'doc_id': 'BOCYL-D-21032025-26', 'date': '2025-03-21', 'doc_number': 26, 'source': 'BOCYL', 'type': 'official_document', 'area': 'AGRARIA', 'consejeria': 'AGRICULTURA Y PESCA', 'title': 'RESOLUCIÓN de 11 de marzo de 2025, de la Dirección General de Producción Agrícola y Ganadera, por la que se hace pública la relación de localidades autorizadas para la producción de patata de siembra en Castilla y León, durante la campaña 2025/2026.'}
# Document BOCYL-D-07032025-16 not found
# Added BOCYL-D-07032025-16 with 3 sections and metadata: {'doc_id': 'BOCYL-D-07032025-16', 'date': '2025-03-07', 'doc_number': 16, 'source': 'BOCYL', 'type': 'official_document', 'area': 'AGRARIA', 'consejeria': 'AGRICULTURA Y PESCA', 'title': 'RESOLUCIÓN de 28 de febrero de 2025, del Servicio Territorial de Agricultura, Ganadería y Desarrollo Rural de Zamora, por la que se aprueba la composición de la comisión local de la zona de concentración parcelaria de Rábano de Aliste (Zamora).'}
# Document BOCYL-D-07032025-17 not found
# Added BOCYL-D-07032025-17 with 3 sections and metadata: {'doc_id': 'BOCYL-D-07032025-17', 'date': '2025-03-07', 'doc_number': 17, 'source': 'BOCYL', 'type': 'official_document', 'area': 'AGRARIA', 'consejeria': 'AGRICULTURA Y PESCA', 'title': 'RESOLUCIÓN de 28 de febrero de 2025, del Servicio Territorial de Agricultura, Ganadería y Desarrollo Rural de Zamora, por la que se aprueba la composición de la comisión local de la zona de concentración parcelaria de Tola (Zamora).'}
# Document BOCYL-D-26022025-18 not found
# Added BOCYL-D-26022025-18 with 3 sections and metadata: {'doc_id': 'BOCYL-D-26022025-18', 'date': '2025-02-26', 'doc_number': 18, 'source': 'BOCYL', 'type': 'official_document', 'area': 'AGRARIA', 'consejeria': 'AGRICULTURA Y PESCA', 'title': 'ANUNCIO del Servicio Territorial de Agricultura, Ganadería y Desarrollo Rural de León, relativo a la apertura del trámite de información pública de la aprobación de las bases provisionales de la concentración parcelaria de la zona de Almanza II (León).'}
# Document BOCYL-D-10022025-2 not found
# Added BOCYL-D-10022025-2 with 59 sections and metadata: {'doc_id': 'BOCYL-D-10022025-2', 'date': '2025-02-10', 'doc_number': 2, 'source': 'BOCYL', 'type': 'official_document', 'area': 'AGRARIA', 'consejeria': 'AGRICULTURA Y PESCA', 'title': 'ORDEN AGR/85/2025, de 27 de enero, por la que se regulan las actividades de formación en materia de bienestar, bioseguridad, higiene y sanidad animal en la Comunidad de Castilla y León.'}
# [{'doc_id': 'BOCYL-D-21042025-1',
#   'sections': 4,
#   'metadata': {'doc_id': 'BOCYL-D-21042025-1',
#    'date': '2025-04-21',
#    'doc_number': 1,
#    'source': 'BOCYL',
#    'type': 'official_document',
#    'area': 'AGRARIA',
#    'consejeria': 'AGRICULTURA Y PESCA',
#    'title': 'ORDEN SAN/378/2025, de 4 de abril, por la que se resuelve convocatoria pública para cubrir, mediante el sistema de libre designación, el puesto de trabajo que se cita.'},
#   'section_metadata': [{'doc_id': 'BOCYL-D-21042025-1',
#     'date': '2025-04-21',
#     'doc_number': 1,
#     'source': 'BOCYL',
#     'type': 'official_document',
#     'area': 'AGRARIA',
#     'consejeria': 'AGRICULTURA Y PESCA',
#     'title': 'ORDEN SAN/378/2025, de 4 de abril, por la que se resuelve convocatoria pública para cubrir, mediante el sistema de libre designación, el puesto de trabajo que se cita.',
#     'heading_level': 1,
#     'heading_hierarchy': 'ORDEN SAN/378/2025, de 4 de abril, por la que se resuelve convocatoria pública para cubrir, mediante el sistema de libre designación, el puesto de trabajo que se cita.',
#     'parent_heading': 'None',
#     'chunk_id': 0,
#     'chunk_total': 4,
#     'heading': 'ORDEN SAN/378/2025, de 4 de abril, por la que se resuelve convocatoria pública para cubrir, mediante el sistema de libre designación, el puesto de trabajo que se cita.'},
#    {'doc_id': 'BOCYL-D-21042025-1',
#     'date': '2025-04-21',
#     'doc_number': 1,
#     'source': 'BOCYL',
#     'type': 'official_document',
#     'area': 'AGRARIA',
#     'consejeria': 'AGRICULTURA Y PESCA',
#     'title': 'ORDEN SAN/378/2025, de 4 de abril, por la que se resuelve convocatoria pública para cubrir, mediante el sistema de libre designación, el puesto de trabajo que se cita.',
#     'heading_level': 3,
#     'heading_hierarchy': 'Introduction | DISPONGO',
#     'parent_heading': 'Introduction',
#     'chunk_id': 1,
#     'chunk_total': 4,
#     'heading': 'DISPONGO'},
#    {'doc_id': 'BOCYL-D-21042025-1',
#     'date': '2025-04-21',
#     'doc_number': 1,
#     'source': 'BOCYL',
#     'type': 'official_document',
#     'area': 'AGRARIA',
#     'consejeria': 'AGRICULTURA Y PESCA',
#     'title': 'ORDEN SAN/378/2025, de 4 de abril, por la que se resuelve convocatoria pública para cubrir, mediante el sistema de libre designación, el puesto de trabajo que se cita.',
#     'heading_level': 3,
#     'heading_hierarchy': 'Introduction | ANEXO | ANEXO',
#     'parent_heading': 'ANEXO',
#     'chunk_id': 2,
#     'chunk_total': 4,
#     'heading': 'ANEXO'},
#    {'doc_id': 'BOCYL-D-21042025-1',
#     'date': '2025-04-21',
#     'doc_number': 1,
#     'source': 'BOCYL',
#     'type': 'official_document',
#     'area': 'AGRARIA',
#     'consejeria': 'AGRICULTURA Y PESCA',
#     'title': 'ORDEN SAN/378/2025, de 4 de abril, por la que se resuelve convocatoria pública para cubrir, mediante el sistema de libre designación, el puesto de trabajo que se cita.',
#     'heading_level': 3,
#     'heading_hierarchy': 'Introduction | D.N.I.  **1401*** | D.N.I.  **1401***',
#     'parent_heading': 'D.N.I.  **1401***',
#     'chunk_id': 3,
#     'chunk_total': 4,
#     'heading': 'D.N.I.  **1401***'}]},
#  {'doc_id': 'BOCYL-D-14042025-56',
#   'sections': 11,
#   'metadata': {'doc_id': 'BOCYL-D-14042025-56',
#    'date': '2025-04-14',
#    'doc_number': 56,
#    'source': 'BOCYL',
#    'type': 'official_document',
#    'area': 'AGRARIA',
#    'consejeria': 'AGRICULTURA Y PESCA',
#    'title': 'RESOLUCIÓN de 7 de abril de 2025, del Servicio Territorial de Agricultura, Ganadería y Desarrollo Rural de Zamora, por la que se convoca asamblea única para la elección de los miembros que van a formar parte del grupo auxiliar de trabajo y de la comisión local, en relación con la concentración parcelaria de la zona de Benegiles II (Zamora).'},
#   'section_metadata': [{'doc_id': 'BOCYL-D-14042025-56',
#     'date': '2025-04-14',
#     'doc_number': 56,
#     'source': 'BOCYL',
#     'type': 'official_document',
#     'area': 'AGRARIA',
#     'consejeria': 'AGRICULTURA Y PESCA',
#     'title': 'RESOLUCIÓN de 7 de abril de 2025, del Servicio Territorial de Agricultura, Ganadería y Desarrollo Rural de Zamora, por la que se convoca asamblea única para la elección de los miembros que van a formar parte del grupo auxiliar de trabajo y de la comisión local, en relación con la concentración parcelaria de la zona de Benegiles II (Zamora).',
#     'heading_level': 1,
#     'heading_hierarchy': 'RESOLUCIÓN de 7 de abril de 2025, del Servicio Territorial de Agricultura, Ganadería y Desarrollo Rural de Zamora, por la que se convoca asamblea única para la elección de los miembros que van a formar parte del grupo auxiliar de trabajo y de la comisión local, en relación con la concentración parcelaria de la zona de Benegiles II (Zamora).',
#     'parent_heading': 'None',
#     'subsection': 'Part 1/2',
#     'chunk_id': 0,
#     'chunk_total': 11,
#     'heading': 'RESOLUCIÓN de 7 de abril de 2025, del Servicio Territorial de Agricultura, Ganadería y Desarrollo Rural de Zamora, por la que se convoca asamblea única para la elección de los miembros que van a formar parte del grupo auxiliar de trabajo y de la comisión local, en relación con la concentración parcelaria de la zona de Benegiles II (Zamora).'},
#    {'doc_id': 'BOCYL-D-14042025-56',
#     'date': '2025-04-14',
#     'doc_number': 56,
#     'source': 'BOCYL',
#     'type': 'official_document',
#     'area': 'AGRARIA',
#     'consejeria': 'AGRICULTURA Y PESCA',
#     'title': 'RESOLUCIÓN de 7 de abril de 2025, del Servicio Territorial de Agricultura, Ganadería y Desarrollo Rural de Zamora, por la que se convoca asamblea única para la elección de los miembros que van a formar parte del grupo auxiliar de trabajo y de la comisión local, en relación con la concentración parcelaria de la zona de Benegiles II (Zamora).',
#     'heading_level': 1,
#     'heading_hierarchy': 'RESOLUCIÓN de 7 de abril de 2025, del Servicio Territorial de Agricultura, Ganadería y Desarrollo Rural de Zamora, por la que se convoca asamblea única para la elección de los miembros que van a formar parte del grupo auxiliar de trabajo y de la comisión local, en relación con la concentración parcelaria de la zona de Benegiles II (Zamora).',
#     'parent_heading': 'None',
#     'subsection': 'Part 2/2',
#     'chunk_id': 1,
#     'chunk_total': 11,
#     'heading': 'RESOLUCIÓN de 7 de abril de 2025, del Servicio Territorial de Agricultura, Ganadería y Desarrollo Rural de Zamora, por la que se convoca asamblea única para la elección de los miembros que van a formar parte del grupo auxiliar de trabajo y de la comisión local, en relación con la concentración parcelaria de la zona de Benegiles II (Zamora).'},
#    {'doc_id': 'BOCYL-D-14042025-56',
#     'date': '2025-04-14',
#     'doc_number': 56,
#     'source': 'BOCYL',
#     'type': 'official_document',
#     'area': 'AGRARIA',
#     'consejeria': 'AGRICULTURA Y PESCA',
#     'title': 'RESOLUCIÓN de 7 de abril de 2025, del Servicio Territorial de Agricultura, Ganadería y Desarrollo Rural de Zamora, por la que se convoca asamblea única para la elección de los miembros que van a formar parte del grupo auxiliar de trabajo y de la comisión local, en relación con la concentración parcelaria de la zona de Benegiles II (Zamora).',
#     'heading_level': 3,
#     'heading_hierarchy': 'Introduction | MUNICIPIO',
#     'parent_heading': 'Introduction',
#     'chunk_id': 2,
#     'chunk_total': 11,
#     'heading': 'MUNICIPIO'},
#    {'doc_id': 'BOCYL-D-14042025-56',
#     'date': '2025-04-14',
#     'doc_number': 56,
#     'source': 'BOCYL',
#     'type': 'official_document',
#     'area': 'AGRARIA',
#     'consejeria': 'AGRICULTURA Y PESCA',
#     'title': 'RESOLUCIÓN de 7 de abril de 2025, del Servicio Territorial de Agricultura, Ganadería y Desarrollo Rural de Zamora, por la que se convoca asamblea única para la elección de los miembros que van a formar parte del grupo auxiliar de trabajo y de la comisión local, en relación con la concentración parcelaria de la zona de Benegiles II (Zamora).',
#     'heading_level': 3,
#     'heading_hierarchy': 'Introduction | PROVINCIA | PROVINCIA',
#     'parent_heading': 'PROVINCIA',
#     'chunk_id': 3,
#     'chunk_total': 11,
#     'heading': 'PROVINCIA'},
#    {'doc_id': 'BOCYL-D-14042025-56',
#     'date': '2025-04-14',
#     'doc_number': 56,
#     'source': 'BOCYL',
#     'type': 'official_document',
#     'area': 'AGRARIA',
#     'consejeria': 'AGRICULTURA Y PESCA',
#     'title': 'RESOLUCIÓN de 7 de abril de 2025, del Servicio Territorial de Agricultura, Ganadería y Desarrollo Rural de Zamora, por la que se convoca asamblea única para la elección de los miembros que van a formar parte del grupo auxiliar de trabajo y de la comisión local, en relación con la concentración parcelaria de la zona de Benegiles II (Zamora).',
#     'heading_level': 3,
#     'heading_hierarchy': 'Introduction | FECHA | FECHA',
#     'parent_heading': 'FECHA',
#     'chunk_id': 4,
#     'chunk_total': 11,
#     'heading': 'FECHA'},
#    {'doc_id': 'BOCYL-D-14042025-56',
#     'date': '2025-04-14',
#     'doc_number': 56,
#     'source': 'BOCYL',
#     'type': 'official_document',
#     'area': 'AGRARIA',
#     'consejeria': 'AGRICULTURA Y PESCA',
#     'title': 'RESOLUCIÓN de 7 de abril de 2025, del Servicio Territorial de Agricultura, Ganadería y Desarrollo Rural de Zamora, por la que se convoca asamblea única para la elección de los miembros que van a formar parte del grupo auxiliar de trabajo y de la comisión local, en relación con la concentración parcelaria de la zona de Benegiles II (Zamora).',
#     'heading_level': 3,
#     'heading_hierarchy': 'Introduction | HORA | HORA',
#     'parent_heading': 'HORA',
#     'chunk_id': 5,
#     'chunk_total': 11,
#     'heading': 'HORA'},
#    {'doc_id': 'BOCYL-D-14042025-56',
#     'date': '2025-04-14',
#     'doc_number': 56,
#     'source': 'BOCYL',
#     'type': 'official_document',
#     'area': 'AGRARIA',
#     'consejeria': 'AGRICULTURA Y PESCA',
#     'title': 'RESOLUCIÓN de 7 de abril de 2025, del Servicio Territorial de Agricultura, Ganadería y Desarrollo Rural de Zamora, por la que se convoca asamblea única para la elección de los miembros que van a formar parte del grupo auxiliar de trabajo y de la comisión local, en relación con la concentración parcelaria de la zona de Benegiles II (Zamora).',
#     'heading_level': 3,
#     'heading_hierarchy': 'Introduction | LUGAR | LUGAR',
#     'parent_heading': 'LUGAR',
#     'chunk_id': 6,
#     'chunk_total': 11,
#     'heading': 'LUGAR'},
#    {'doc_id': 'BOCYL-D-14042025-56',
#     'date': '2025-04-14',
#     'doc_number': 56,
#     'source': 'BOCYL',
#     'type': 'official_document',
#     'area': 'AGRARIA',
#     'consejeria': 'AGRICULTURA Y PESCA',
#     'title': 'RESOLUCIÓN de 7 de abril de 2025, del Servicio Territorial de Agricultura, Ganadería y Desarrollo Rural de Zamora, por la que se convoca asamblea única para la elección de los miembros que van a formar parte del grupo auxiliar de trabajo y de la comisión local, en relación con la concentración parcelaria de la zona de Benegiles II (Zamora).',
#     'heading_level': 3,
#     'heading_hierarchy': 'Introduction | BENEGILES | BENEGILES',
#     'parent_heading': 'BENEGILES',
#     'chunk_id': 7,
#     'chunk_total': 11,
#     'heading': 'BENEGILES'},
#    {'doc_id': 'BOCYL-D-14042025-56',
#     'date': '2025-04-14',
#     'doc_number': 56,
#     'source': 'BOCYL',
#     'type': 'official_document',
#     'area': 'AGRARIA',
#     'consejeria': 'AGRICULTURA Y PESCA',
#     'title': 'RESOLUCIÓN de 7 de abril de 2025, del Servicio Territorial de Agricultura, Ganadería y Desarrollo Rural de Zamora, por la que se convoca asamblea única para la elección de los miembros que van a formar parte del grupo auxiliar de trabajo y de la comisión local, en relación con la concentración parcelaria de la zona de Benegiles II (Zamora).',
#     'heading_level': 3,
#     'heading_hierarchy': 'Introduction | ZAMORA | ZAMORA',
#     'parent_heading': 'ZAMORA',
#     'chunk_id': 8,
#     'chunk_total': 11,
#     'heading': 'ZAMORA'},
#    {'doc_id': 'BOCYL-D-14042025-56',
#     'date': '2025-04-14',
#     'doc_number': 56,
#     'source': 'BOCYL',
#     'type': 'official_document',
#     'area': 'AGRARIA',
#     'consejeria': 'AGRICULTURA Y PESCA',
#     'title': 'RESOLUCIÓN de 7 de abril de 2025, del Servicio Territorial de Agricultura, Ganadería y Desarrollo Rural de Zamora, por la que se convoca asamblea única para la elección de los miembros que van a formar parte del grupo auxiliar de trabajo y de la comisión local, en relación con la concentración parcelaria de la zona de Benegiles II (Zamora).',
#     'heading_level': 3,
#     'heading_hierarchy': 'Introduction | 12 DE MAYO DE 2025 | 12 DE MAYO DE 2025',
#     'parent_heading': '12 DE MAYO DE 2025',
#     'chunk_id': 9,
#     'chunk_total': 11,
#     'heading': '12 DE MAYO DE 2025'},
#    {'doc_id': 'BOCYL-D-14042025-56',
#     'date': '2025-04-14',
#     'doc_number': 56,
#     'source': 'BOCYL',
#     'type': 'official_document',
#     'area': 'AGRARIA',
#     'consejeria': 'AGRICULTURA Y PESCA',
#     'title': 'RESOLUCIÓN de 7 de abril de 2025, del Servicio Territorial de Agricultura, Ganadería y Desarrollo Rural de Zamora, por la que se convoca asamblea única para la elección de los miembros que van a formar parte del grupo auxiliar de trabajo y de la comisión local, en relación con la concentración parcelaria de la zona de Benegiles II (Zamora).',
#     'heading_level': 3,
#     'heading_hierarchy': 'Introduction | AYUNTAMIENTO | AYUNTAMIENTO',
#     'parent_heading': 'AYUNTAMIENTO',
#     'chunk_id': 10,
#     'chunk_total': 11,
#     'heading': 'AYUNTAMIENTO'}]},
#  {'doc_id': 'BOCYL-D-11042025-15',
#   'sections': 2,
#   'metadata': {'doc_id': 'BOCYL-D-11042025-15',
#    'date': '2025-04-11',
#    'doc_number': 15,
#    'source': 'BOCYL',
#    'type': 'official_document',
#    'area': 'AGRARIA',
#    'consejeria': 'AGRICULTURA Y PESCA',
#    'title': 'EXTRACTO de la Orden de 8 de abril de 2025, de la Consejería de Agricultura, Ganadería y Desarrollo Rural, por la que se convocan las ayudas a la cosecha en verde de viñedos en la Comunidad de Castilla y León para la vendimia 2025.'},
#   'section_metadata': [{'doc_id': 'BOCYL-D-11042025-15',
#     'date': '2025-04-11',
#     'doc_number': 15,
#     'source': 'BOCYL',
#     'type': 'official_document',
#     'area': 'AGRARIA',
#     'consejeria': 'AGRICULTURA Y PESCA',
#     'title': 'EXTRACTO de la Orden de 8 de abril de 2025, de la Consejería de Agricultura, Ganadería y Desarrollo Rural, por la que se convocan las ayudas a la cosecha en verde de viñedos en la Comunidad de Castilla y León para la vendimia 2025.',
#     'heading_level': 1,
#     'heading_hierarchy': 'EXTRACTO de la Orden de 8 de abril de 2025, de la Consejería de Agricultura, Ganadería y Desarrollo Rural, por la que se convocan las ayudas a la cosecha en verde de viñedos en la Comunidad de Castilla y León para la vendimia 2025.',
#     'parent_heading': 'None',
#     'subsection': 'Part 1/2',
#     'chunk_id': 0,
#     'chunk_total': 2,
#     'heading': 'EXTRACTO de la Orden de 8 de abril de 2025, de la Consejería de Agricultura, Ganadería y Desarrollo Rural, por la que se convocan las ayudas a la cosecha en verde de viñedos en la Comunidad de Castilla y León para la vendimia 2025.'},
#    {'doc_id': 'BOCYL-D-11042025-15',
#     'date': '2025-04-11',
#     'doc_number': 15,
#     'source': 'BOCYL',
#     'type': 'official_document',
#     'area': 'AGRARIA',
#     'consejeria': 'AGRICULTURA Y PESCA',
#     'title': 'EXTRACTO de la Orden de 8 de abril de 2025, de la Consejería de Agricultura, Ganadería y Desarrollo Rural, por la que se convocan las ayudas a la cosecha en verde de viñedos en la Comunidad de Castilla y León para la vendimia 2025.',
#     'heading_level': 1,
#     'heading_hierarchy': 'EXTRACTO de la Orden de 8 de abril de 2025, de la Consejería de Agricultura, Ganadería y Desarrollo Rural, por la que se convocan las ayudas a la cosecha en verde de viñedos en la Comunidad de Castilla y León para la vendimia 2025.',
#     'parent_heading': 'None',
#     'subsection': 'Part 2/2',
#     'chunk_id': 1,
#     'chunk_total': 2,
#     'heading': 'EXTRACTO de la Orden de 8 de abril de 2025, de la Consejería de Agricultura, Ganadería y Desarrollo Rural, por la que se convocan las ayudas a la cosecha en verde de viñedos en la Comunidad de Castilla y León para la vendimia 2025.'}]},
#  {'doc_id': 'BOCYL-D-07042025-29',
#   'sections': 11,
#   'metadata': {'doc_id': 'BOCYL-D-07042025-29',
#    'date': '2025-04-07',
#    'doc_number': 29,
#    'source': 'BOCYL',
#    'type': 'official_document',
#    'area': 'AGRARIA',
#    'consejeria': 'AGRICULTURA Y PESCA',
#    'title': 'RESOLUCIÓN de 31 de marzo de 2025, del Servicio Territorial de Agricultura, Ganadería y Desarrollo Rural de Zamora, por la que se convoca asamblea única para la elección de los miembros que van a formar parte de los grupos auxiliares de trabajo y de la comisión local en relación con la concentración parcelaria de la zona de San Román de los Infantes (Zamora).'},
#   'section_metadata': [{'doc_id': 'BOCYL-D-07042025-29',
#     'date': '2025-04-07',
#     'doc_number': 29,
#     'source': 'BOCYL',
#     'type': 'official_document',
#     'area': 'AGRARIA',
#     'consejeria': 'AGRICULTURA Y PESCA',
#     'title': 'RESOLUCIÓN de 31 de marzo de 2025, del Servicio Territorial de Agricultura, Ganadería y Desarrollo Rural de Zamora, por la que se convoca asamblea única para la elección de los miembros que van a formar parte de los grupos auxiliares de trabajo y de la comisión local en relación con la concentración parcelaria de la zona de San Román de los Infantes (Zamora).',
#     'heading_level': 1,
#     'heading_hierarchy': 'RESOLUCIÓN de 31 de marzo de 2025, del Servicio Territorial de Agricultura, Ganadería y Desarrollo Rural de Zamora, por la que se convoca asamblea única para la elección de los miembros que van a formar parte de los grupos auxiliares de trabajo y de la comisión local en relación con la concentración parcelaria de la zona de San Román de los Infantes (Zamora).',
#     'parent_heading': 'None',
#     'subsection': 'Part 1/2',
#     'chunk_id': 0,
#     'chunk_total': 11,
#     'heading': 'RESOLUCIÓN de 31 de marzo de 2025, del Servicio Territorial de Agricultura, Ganadería y Desarrollo Rural de Zamora, por la que se convoca asamblea única para la elección de los miembros que van a formar parte de los grupos auxiliares de trabajo y de la comisión local en relación con la concentración parcelaria de la zona de San Román de los Infantes (Zamora).'},
#    {'doc_id': 'BOCYL-D-07042025-29',
#     'date': '2025-04-07',
#     'doc_number': 29,
#     'source': 'BOCYL',
#     'type': 'official_document',
#     'area': 'AGRARIA',
#     'consejeria': 'AGRICULTURA Y PESCA',
#     'title': 'RESOLUCIÓN de 31 de marzo de 2025, del Servicio Territorial de Agricultura, Ganadería y Desarrollo Rural de Zamora, por la que se convoca asamblea única para la elección de los miembros que van a formar parte de los grupos auxiliares de trabajo y de la comisión local en relación con la concentración parcelaria de la zona de San Román de los Infantes (Zamora).',
#     'heading_level': 1,
#     'heading_hierarchy': 'RESOLUCIÓN de 31 de marzo de 2025, del Servicio Territorial de Agricultura, Ganadería y Desarrollo Rural de Zamora, por la que se convoca asamblea única para la elección de los miembros que van a formar parte de los grupos auxiliares de trabajo y de la comisión local en relación con la concentración parcelaria de la zona de San Román de los Infantes (Zamora).',
#     'parent_heading': 'None',
#     'subsection': 'Part 2/2',
#     'chunk_id': 1,
#     'chunk_total': 11,
#     'heading': 'RESOLUCIÓN de 31 de marzo de 2025, del Servicio Territorial de Agricultura, Ganadería y Desarrollo Rural de Zamora, por la que se convoca asamblea única para la elección de los miembros que van a formar parte de los grupos auxiliares de trabajo y de la comisión local en relación con la concentración parcelaria de la zona de San Román de los Infantes (Zamora).'},
#    {'doc_id': 'BOCYL-D-07042025-29',
#     'date': '2025-04-07',
#     'doc_number': 29,
#     'source': 'BOCYL',
#     'type': 'official_document',
#     'area': 'AGRARIA',
#     'consejeria': 'AGRICULTURA Y PESCA',
#     'title': 'RESOLUCIÓN de 31 de marzo de 2025, del Servicio Territorial de Agricultura, Ganadería y Desarrollo Rural de Zamora, por la que se convoca asamblea única para la elección de los miembros que van a formar parte de los grupos auxiliares de trabajo y de la comisión local en relación con la concentración parcelaria de la zona de San Román de los Infantes (Zamora).',
#     'heading_level': 3,
#     'heading_hierarchy': 'Introduction | MUNICIPIO',
#     'parent_heading': 'Introduction',
#     'chunk_id': 2,
#     'chunk_total': 11,
#     'heading': 'MUNICIPIO'},
#    {'doc_id': 'BOCYL-D-07042025-29',
#     'date': '2025-04-07',
#     'doc_number': 29,
#     'source': 'BOCYL',
#     'type': 'official_document',
#     'area': 'AGRARIA',
#     'consejeria': 'AGRICULTURA Y PESCA',
#     'title': 'RESOLUCIÓN de 31 de marzo de 2025, del Servicio Territorial de Agricultura, Ganadería y Desarrollo Rural de Zamora, por la que se convoca asamblea única para la elección de los miembros que van a formar parte de los grupos auxiliares de trabajo y de la comisión local en relación con la concentración parcelaria de la zona de San Román de los Infantes (Zamora).',
#     'heading_level': 3,
#     'heading_hierarchy': 'Introduction | PROVINCIA | PROVINCIA',
#     'parent_heading': 'PROVINCIA',
#     'chunk_id': 3,
#     'chunk_total': 11,
#     'heading': 'PROVINCIA'},
#    {'doc_id': 'BOCYL-D-07042025-29',
#     'date': '2025-04-07',
#     'doc_number': 29,
#     'source': 'BOCYL',
#     'type': 'official_document',
#     'area': 'AGRARIA',
#     'consejeria': 'AGRICULTURA Y PESCA',
#     'title': 'RESOLUCIÓN de 31 de marzo de 2025, del Servicio Territorial de Agricultura, Ganadería y Desarrollo Rural de Zamora, por la que se convoca asamblea única para la elección de los miembros que van a formar parte de los grupos auxiliares de trabajo y de la comisión local en relación con la concentración parcelaria de la zona de San Román de los Infantes (Zamora).',
#     'heading_level': 3,
#     'heading_hierarchy': 'Introduction | FECHA | FECHA',
#     'parent_heading': 'FECHA',
#     'chunk_id': 4,
#     'chunk_total': 11,
#     'heading': 'FECHA'},
#    {'doc_id': 'BOCYL-D-07042025-29',
#     'date': '2025-04-07',
#     'doc_number': 29,
#     'source': 'BOCYL',
#     'type': 'official_document',
#     'area': 'AGRARIA',
#     'consejeria': 'AGRICULTURA Y PESCA',
#     'title': 'RESOLUCIÓN de 31 de marzo de 2025, del Servicio Territorial de Agricultura, Ganadería y Desarrollo Rural de Zamora, por la que se convoca asamblea única para la elección de los miembros que van a formar parte de los grupos auxiliares de trabajo y de la comisión local en relación con la concentración parcelaria de la zona de San Román de los Infantes (Zamora).',
#     'heading_level': 3,
#     'heading_hierarchy': 'Introduction | HORA | HORA',
#     'parent_heading': 'HORA',
#     'chunk_id': 5,
#     'chunk_total': 11,
#     'heading': 'HORA'},
#    {'doc_id': 'BOCYL-D-07042025-29',
#     'date': '2025-04-07',
#     'doc_number': 29,
#     'source': 'BOCYL',
#     'type': 'official_document',
#     'area': 'AGRARIA',
#     'consejeria': 'AGRICULTURA Y PESCA',
#     'title': 'RESOLUCIÓN de 31 de marzo de 2025, del Servicio Territorial de Agricultura, Ganadería y Desarrollo Rural de Zamora, por la que se convoca asamblea única para la elección de los miembros que van a formar parte de los grupos auxiliares de trabajo y de la comisión local en relación con la concentración parcelaria de la zona de San Román de los Infantes (Zamora).',
#     'heading_level': 3,
#     'heading_hierarchy': 'Introduction | LUGAR | LUGAR',
#     'parent_heading': 'LUGAR',
#     'chunk_id': 6,
#     'chunk_total': 11,
#     'heading': 'LUGAR'},
#    {'doc_id': 'BOCYL-D-07042025-29',
#     'date': '2025-04-07',
#     'doc_number': 29,
#     'source': 'BOCYL',
#     'type': 'official_document',
#     'area': 'AGRARIA',
#     'consejeria': 'AGRICULTURA Y PESCA',
#     'title': 'RESOLUCIÓN de 31 de marzo de 2025, del Servicio Territorial de Agricultura, Ganadería y Desarrollo Rural de Zamora, por la que se convoca asamblea única para la elección de los miembros que van a formar parte de los grupos auxiliares de trabajo y de la comisión local en relación con la concentración parcelaria de la zona de San Román de los Infantes (Zamora).',
#     'heading_level': 3,
#     'heading_hierarchy': 'Introduction | SAN ROMÁN DE LOS INFANTES | SAN ROMÁN DE LOS INFANTES',
#     'parent_heading': 'SAN ROMÁN DE LOS INFANTES',
#     'chunk_id': 7,
#     'chunk_total': 11,
#     'heading': 'SAN ROMÁN DE LOS INFANTES'},
#    {'doc_id': 'BOCYL-D-07042025-29',
#     'date': '2025-04-07',
#     'doc_number': 29,
#     'source': 'BOCYL',
#     'type': 'official_document',
#     'area': 'AGRARIA',
#     'consejeria': 'AGRICULTURA Y PESCA',
#     'title': 'RESOLUCIÓN de 31 de marzo de 2025, del Servicio Territorial de Agricultura, Ganadería y Desarrollo Rural de Zamora, por la que se convoca asamblea única para la elección de los miembros que van a formar parte de los grupos auxiliares de trabajo y de la comisión local en relación con la concentración parcelaria de la zona de San Román de los Infantes (Zamora).',
#     'heading_level': 3,
#     'heading_hierarchy': 'Introduction | ZAMORA | ZAMORA',
#     'parent_heading': 'ZAMORA',
#     'chunk_id': 8,
#     'chunk_total': 11,
#     'heading': 'ZAMORA'},
#    {'doc_id': 'BOCYL-D-07042025-29',
#     'date': '2025-04-07',
#     'doc_number': 29,
#     'source': 'BOCYL',
#     'type': 'official_document',
#     'area': 'AGRARIA',
#     'consejeria': 'AGRICULTURA Y PESCA',
#     'title': 'RESOLUCIÓN de 31 de marzo de 2025, del Servicio Territorial de Agricultura, Ganadería y Desarrollo Rural de Zamora, por la que se convoca asamblea única para la elección de los miembros que van a formar parte de los grupos auxiliares de trabajo y de la comisión local en relación con la concentración parcelaria de la zona de San Román de los Infantes (Zamora).',
#     'heading_level': 3,
#     'heading_hierarchy': 'Introduction | 06 DE MAYO DE 2025 | 06 DE MAYO DE 2025',
#     'parent_heading': '06 DE MAYO DE 2025',
#     'chunk_id': 9,
#     'chunk_total': 11,
#     'heading': '06 DE MAYO DE 2025'},
#    {'doc_id': 'BOCYL-D-07042025-29',
#     'date': '2025-04-07',
#     'doc_number': 29,
#     'source': 'BOCYL',
#     'type': 'official_document',
#     'area': 'AGRARIA',
#     'consejeria': 'AGRICULTURA Y PESCA',
#     'title': 'RESOLUCIÓN de 31 de marzo de 2025, del Servicio Territorial de Agricultura, Ganadería y Desarrollo Rural de Zamora, por la que se convoca asamblea única para la elección de los miembros que van a formar parte de los grupos auxiliares de trabajo y de la comisión local en relación con la concentración parcelaria de la zona de San Román de los Infantes (Zamora).',
#     'heading_level': 3,
#     'heading_hierarchy': 'Introduction | ANTIGUAS ESCUELAS | ANTIGUAS ESCUELAS',
#     'parent_heading': 'ANTIGUAS ESCUELAS',
#     'chunk_id': 10,
#     'chunk_total': 11,
#     'heading': 'ANTIGUAS ESCUELAS'}]},
#  {'doc_id': 'BOCYL-D-02042025-23',
#   'sections': 476,
#   'metadata': {'doc_id': 'BOCYL-D-02042025-23',
#    'date': '2025-04-02',
#    'doc_number': 23,
#    'source': 'BOCYL',
#    'type': 'official_document',
#    'area': 'AGRARIA',
#    'consejeria': 'AGRICULTURA Y PESCA',
#    'title': 'RESOLUCIÓN de 19 de marzo de 2025, de la Dirección General de Política Agraria Comunitaria, por la que se establece la clasificación de los criterios de evaluación de gravedad, alcance y persistencia, y el cálculo de las reducciones a los efectos de aplicar la condicionalidad reforzada y social de las ayudas de la Política Agrícola Común, en el año 2024.'},
#   'section_metadata': [{'doc_id': 'BOCYL-D-02042025-23',
#     'date': '2025-04-02',
#     'doc_number': 23,
#     'source': 'BOCYL',
#     'type': 'official_document',
#     'area': 'AGRARIA',
#     'consejeria': 'AGRICULTURA Y PESCA',
#     'title': 'RESOLUCIÓN de 19 de marzo de 2025, de la Dirección General de Política Agraria Comunitaria, por la que se establece la clasificación de los criterios de evaluación de gravedad, alcance y persistencia, y el cálculo de las reducciones a los efectos de aplicar la condicionalidad reforzada y social de las ayudas de la Política Agrícola Común, en el año 2024.',
#     'heading_level': 1,
#     'heading_hierarchy': 'RESOLUCIÓN de 19 de marzo de 2025, de la Dirección General de Política Agraria Comunitaria, por la que se establece la clasificación de los criterios de evaluación de gravedad, alcance y persistencia, y el cálculo de las reducciones a los efectos de aplicar la condicionalidad reforzada y social de las ayudas de la Política Agrícola Común, en el año 2024.',
#     'parent_heading': 'None',
#     'subsection': 'Part 1/2',
#     'chunk_id': 0,
#     'chunk_total': 476,
#     'heading': 'RESOLUCIÓN de 19 de marzo de 2025, de la Dirección General de Política Agraria Comunitaria, por la que se establece la clasificación de los criterios de evaluación de gravedad, alcance y persistencia, y el cálculo de las reducciones a los efectos de aplicar la condicionalidad reforzada y social de las ayudas de la Política Agrícola Común, en el año 2024.'},
#    {'doc_id': 'BOCYL-D-02042025-23',
#     'date': '2025-04-02',
#     'doc_number': 23,
#     'source': 'BOCYL',
#     'type': 'official_document',
#     'area': 'AGRARIA',
#     'consejeria': 'AGRICULTURA Y PESCA',
#     'title': 'RESOLUCIÓN de 19 de marzo de 2025, de la Dirección General de Política Agraria Comunitaria, por la que se establece la clasificación de los criterios de evaluación de gravedad, alcance y persistencia, y el cálculo de las reducciones a los efectos de aplicar la condicionalidad reforzada y social de las ayudas de la Política Agrícola Común, en el año 2024.',
#     'heading_level': 1,
#     'heading_hierarchy': 'RESOLUCIÓN de 19 de marzo de 2025, de la Dirección General de Política Agraria Comunitaria, por la que se establece la clasificación de los criterios de evaluación de gravedad, alcance y persistencia, y el cálculo de las reducciones a los efectos de aplicar la condicionalidad reforzada y social de las ayudas de la Política Agrícola Común, en el año 2024.',
#     'parent_heading': 'None',
#     'subsection': 'Part 2/2',
#     'chunk_id': 1,
#     'chunk_total': 476,
#     'heading': 'RESOLUCIÓN de 19 de marzo de 2025, de la Dirección General de Política Agraria Comunitaria, por la que se establece la clasificación de los criterios de evaluación de gravedad, alcance y persistencia, y el cálculo de las reducciones a los efectos de aplicar la condicionalidad reforzada y social de las ayudas de la Política Agrícola Común, en el año 2024.'},
#    {'doc_id': 'BOCYL-D-02042025-23',
#     'date': '2025-04-02',
#     'doc_number': 23,
#     'source': 'BOCYL',
#     'type': 'official_document',
#     'area': 'AGRARIA',
#     'consejeria': 'AGRICULTURA Y PESCA',
#     'title': 'RESOLUCIÓN de 19 de marzo de 2025, de la Dirección General de Política Agraria Comunitaria, por la que se establece la clasificación de los criterios de evaluación de gravedad, alcance y persistencia, y el cálculo de las reducciones a los efectos de aplicar la condicionalidad reforzada y social de las ayudas de la Política Agrícola Común, en el año 2024.',
#     'heading_level': 3,
#     'heading_hierarchy': 'Introduction | RESUELVO',
#     'parent_heading': 'Introduction',
#     'chunk_id': 2,
#     'chunk_total': 476,
#     'heading': 'RESUELVO'},
#    {'doc_id': 'BOCYL-D-02042025-23',
#     'date': '2025-04-02',
#     'doc_number': 23,
#     'source': 'BOCYL',
#     'type': 'official_document',
#     'area': 'AGRARIA',
#     'consejeria': 'AGRICULTURA Y PESCA',
#     'title': 'RESOLUCIÓN de 19 de marzo de 2025, de la Dirección General de Política Agraria Comunitaria, por la que se establece la clasificación de los criterios de evaluación de gravedad, alcance y persistencia, y el cálculo de las reducciones a los efectos de aplicar la condicionalidad reforzada y social de las ayudas de la Política Agrícola Común, en el año 2024.',
#     'heading_level': 3,
#     'heading_hierarchy': 'Introduction | ANEXO I | ANEXO I',
#     'parent_heading': 'ANEXO I',
#     'chunk_id': 3,
#     'chunk_total': 476,
#     'heading': 'ANEXO I'},
#    {'doc_id': 'BOCYL-D-02042025-23',
#     'date': '2025-04-02',
#     'doc_number': 23,
#     'source': 'BOCYL',
#     'type': 'official_document',
#     'area': 'AGRARIA',
#     'consejeria': 'AGRICULTURA Y PESCA',
#     'title': 'RESOLUCIÓN de 19 de marzo de 2025, de la Dirección General de Política Agraria Comunitaria, por la que se establece la clasificación de los criterios de evaluación de gravedad, alcance y persistencia, y el cálculo de las reducciones a los efectos de aplicar la condicionalidad reforzada y social de las ayudas de la Política Agrícola Común, en el año 2024.',
#     'heading_level': 3,
#     'heading_hierarchy': 'Introduction | 1) NIVELES DE GRAVEDAD, ALCANCE Y PERSISTENCIA (GAP). | 1) NIVELES DE GRAVEDAD, ALCANCE Y PERSISTENCIA (GAP).',
#     'parent_heading': '1) NIVELES DE GRAVEDAD, ALCANCE Y PERSISTENCIA (GAP).',
#     'chunk_id': 4,
#     'chunk_total': 476,
#     'heading': '1) NIVELES DE GRAVEDAD, ALCANCE Y PERSISTENCIA (GAP).'},
#    {'doc_id': 'BOCYL-D-02042025-23',
#     'date': '2025-04-02',
#     'doc_number': 23,
#     'source': 'BOCYL',
#     'type': 'official_document',
#     'area': 'AGRARIA',
#     'consejeria': 'AGRICULTURA Y PESCA',
#     'title': 'RESOLUCIÓN de 19 de marzo de 2025, de la Dirección General de Política Agraria Comunitaria, por la que se establece la clasificación de los criterios de evaluación de gravedad, alcance y persistencia, y el cálculo de las reducciones a los efectos de aplicar la condicionalidad reforzada y social de las ayudas de la Política Agrícola Común, en el año 2024.',
#     'heading_level': 3,
#     'heading_hierarchy': 'Introduction | A | A',
#     'parent_heading': 'A',
#     'chunk_id': 5,
#     'chunk_total': 476,
#     'heading': 'A'},
#    {'doc_id': 'BOCYL-D-02042025-23',
#     'date': '2025-04-02',
#     'doc_number': 23,
#     'source': 'BOCYL',
#     'type': 'official_document',
#     'area': 'AGRARIA',
#     'consejeria': 'AGRICULTURA Y PESCA',
#     'title': 'RESOLUCIÓN de 19 de marzo de 2025, de la Dirección General de Política Agraria Comunitaria, por la que se establece la clasificación de los criterios de evaluación de gravedad, alcance y persistencia, y el cálculo de las reducciones a los efectos de aplicar la condicionalidad reforzada y social de las ayudas de la Política Agrícola Común, en el año 2024.',
#     'heading_level': 3,
#     'heading_hierarchy': 'Introduction | B | B',
#     'parent_heading': 'B',
#     'chunk_id': 6,
#     'chunk_total': 476,
#     'heading': 'B'},
#    {'doc_id': 'BOCYL-D-02042025-23',
#     'date': '2025-04-02',
#     'doc_number': 23,
#     'source': 'BOCYL',
#     'type': 'official_document',
#     'area': 'AGRARIA',
#     'consejeria': 'AGRICULTURA Y PESCA',
#     'title': 'RESOLUCIÓN de 19 de marzo de 2025, de la Dirección General de Política Agraria Comunitaria, por la que se establece la clasificación de los criterios de evaluación de gravedad, alcance y persistencia, y el cálculo de las reducciones a los efectos de aplicar la condicionalidad reforzada y social de las ayudas de la Política Agrícola Común, en el año 2024.',
#     'heading_level': 3,
#     'heading_hierarchy': 'Introduction | C | C',
#     'parent_heading': 'C',
#     'chunk_id': 7,
#     'chunk_total': 476,
#     'heading': 'C'},
#    {'doc_id': 'BOCYL-D-02042025-23',
#     'date': '2025-04-02',
#     'doc_number': 23,
#     'source': 'BOCYL',
#     'type': 'official_document',
#     'area': 'AGRARIA',
#     'consejeria': 'AGRICULTURA Y PESCA',
#     'title': 'RESOLUCIÓN de 19 de marzo de 2025, de la Dirección General de Política Agraria Comunitaria, por la que se establece la clasificación de los criterios de evaluación de gravedad, alcance y persistencia, y el cálculo de las reducciones a los efectos de aplicar la condicionalidad reforzada y social de las ayudas de la Política Agrícola Común, en el año 2024.',
#     'heading_level': 3,
#     'heading_hierarchy': 'Introduction | A | A',
#     'parent_heading': 'A',
#     'chunk_id': 8,
#     'chunk_total': 476,
#     'heading': 'A'},
#    {'doc_id': 'BOCYL-D-02042025-23',
#     'date': '2025-04-02',
#     'doc_number': 23,
#     'source': 'BOCYL',
#     'type': 'official_document',
#     'area': 'AGRARIA',
#     'consejeria': 'AGRICULTURA Y PESCA',
#     'title': 'RESOLUCIÓN de 19 de marzo de 2025, de la Dirección General de Política Agraria Comunitaria, por la que se establece la clasificación de los criterios de evaluación de gravedad, alcance y persistencia, y el cálculo de las reducciones a los efectos de aplicar la condicionalidad reforzada y social de las ayudas de la Política Agrícola Común, en el año 2024.',
#     'heading_level': 3,
#     'heading_hierarchy': 'Introduction | B | B',
#     'parent_heading': 'B',
#     'chunk_id': 9,
#     'chunk_total': 476,
#     'heading': 'B'},
#    {'doc_id': 'BOCYL-D-02042025-23',
#     'date': '2025-04-02',
#     'doc_number': 23,
#     'source': 'BOCYL',
#     'type': 'official_document',
#     'area': 'AGRARIA',
#     'consejeria': 'AGRICULTURA Y PESCA',
# ...
#     'chunk_id': 36,
#     'chunk_total': 59,
#     'heading': 'Artículo 19. Emisión de duplicados.'},
#    {'doc_id': 'BOCYL-D-10022025-2',
#     'date': '2025-02-10',
#     'doc_number': 2,
#     'source': 'BOCYL',
#     'type': 'official_document',
#     'area': 'AGRARIA',
#     'consejeria': 'AGRICULTURA Y PESCA',
#     'title': 'ORDEN AGR/85/2025, de 27 de enero, por la que se regulan las actividades de formación en materia de bienestar, bioseguridad, higiene y sanidad animal en la Comunidad de Castilla y León.',
#     'heading_level': 3,
#     'heading_hierarchy': 'Introduction | Artículo 19. Emisión de duplicados. | CAPÍTULO V | CAPÍTULO V',
#     'parent_heading': 'CAPÍTULO V',
#     'chunk_id': 37,
#     'chunk_total': 59,
#     'heading': 'CAPÍTULO V'},
#    {'doc_id': 'BOCYL-D-10022025-2',
#     'date': '2025-02-10',
#     'doc_number': 2,
#     'source': 'BOCYL',
#     'type': 'official_document',
#     'area': 'AGRARIA',
#     'consejeria': 'AGRICULTURA Y PESCA',
#     'title': 'ORDEN AGR/85/2025, de 27 de enero, por la que se regulan las actividades de formación en materia de bienestar, bioseguridad, higiene y sanidad animal en la Comunidad de Castilla y León.',
#     'heading_level': 2,
#     'heading_hierarchy': 'Introduction | Artículo 20. Presentación y tramitación de solicitudes, declaraciones responsables, comunicaciones y documentación. | Artículo 20. Presentación y tramitación de solicitudes, declaraciones responsables, comunicaciones y documentación.',
#     'parent_heading': 'Artículo 20. Presentación y tramitación de solicitudes, declaraciones responsables, comunicaciones y documentación.',
#     'subsection': 'Part 1/2',
#     'chunk_id': 38,
#     'chunk_total': 59,
#     'heading': 'Artículo 20. Presentación y tramitación de solicitudes, declaraciones responsables, comunicaciones y documentación.'},
#    {'doc_id': 'BOCYL-D-10022025-2',
#     'date': '2025-02-10',
#     'doc_number': 2,
#     'source': 'BOCYL',
#     'type': 'official_document',
#     'area': 'AGRARIA',
#     'consejeria': 'AGRICULTURA Y PESCA',
#     'title': 'ORDEN AGR/85/2025, de 27 de enero, por la que se regulan las actividades de formación en materia de bienestar, bioseguridad, higiene y sanidad animal en la Comunidad de Castilla y León.',
#     'heading_level': 2,
#     'heading_hierarchy': 'Introduction | Artículo 20. Presentación y tramitación de solicitudes, declaraciones responsables, comunicaciones y documentación. | Artículo 20. Presentación y tramitación de solicitudes, declaraciones responsables, comunicaciones y documentación.',
#     'parent_heading': 'Artículo 20. Presentación y tramitación de solicitudes, declaraciones responsables, comunicaciones y documentación.',
#     'subsection': 'Part 2/2',
#     'chunk_id': 39,
#     'chunk_total': 59,
#     'heading': 'Artículo 20. Presentación y tramitación de solicitudes, declaraciones responsables, comunicaciones y documentación.'},
#    {'doc_id': 'BOCYL-D-10022025-2',
#     'date': '2025-02-10',
#     'doc_number': 2,
#     'source': 'BOCYL',
#     'type': 'official_document',
#     'area': 'AGRARIA',
#     'consejeria': 'AGRICULTURA Y PESCA',
#     'title': 'ORDEN AGR/85/2025, de 27 de enero, por la que se regulan las actividades de formación en materia de bienestar, bioseguridad, higiene y sanidad animal en la Comunidad de Castilla y León.',
#     'heading_level': 2,
#     'heading_hierarchy': 'Introduction | Artículo 21. Notificación electrónica. | Artículo 21. Notificación electrónica.',
#     'parent_heading': 'Artículo 21. Notificación electrónica.',
#     'chunk_id': 40,
#     'chunk_total': 59,
#     'heading': 'Artículo 21. Notificación electrónica.'},
#    {'doc_id': 'BOCYL-D-10022025-2',
#     'date': '2025-02-10',
#     'doc_number': 2,
#     'source': 'BOCYL',
#     'type': 'official_document',
#     'area': 'AGRARIA',
#     'consejeria': 'AGRICULTURA Y PESCA',
#     'title': 'ORDEN AGR/85/2025, de 27 de enero, por la que se regulan las actividades de formación en materia de bienestar, bioseguridad, higiene y sanidad animal en la Comunidad de Castilla y León.',
#     'heading_level': 3,
#     'heading_hierarchy': 'Introduction | Artículo 21. Notificación electrónica. | DISPOSICIONES ADICIONALES | DISPOSICIONES ADICIONALES',
#     'parent_heading': 'DISPOSICIONES ADICIONALES',
#     'chunk_id': 41,
#     'chunk_total': 59,
#     'heading': 'DISPOSICIONES ADICIONALES'},
#    {'doc_id': 'BOCYL-D-10022025-2',
#     'date': '2025-02-10',
#     'doc_number': 2,
#     'source': 'BOCYL',
#     'type': 'official_document',
#     'area': 'AGRARIA',
#     'consejeria': 'AGRICULTURA Y PESCA',
#     'title': 'ORDEN AGR/85/2025, de 27 de enero, por la que se regulan las actividades de formación en materia de bienestar, bioseguridad, higiene y sanidad animal en la Comunidad de Castilla y León.',
#     'heading_level': 3,
#     'heading_hierarchy': 'Introduction | Artículo 21. Notificación electrónica. | DISPOSICIÓN TRANSITORIA. | DISPOSICIÓN TRANSITORIA.',
#     'parent_heading': 'DISPOSICIÓN TRANSITORIA.',
#     'chunk_id': 42,
#     'chunk_total': 59,
#     'heading': 'DISPOSICIÓN TRANSITORIA.'},
#    {'doc_id': 'BOCYL-D-10022025-2',
#     'date': '2025-02-10',
#     'doc_number': 2,
#     'source': 'BOCYL',
#     'type': 'official_document',
#     'area': 'AGRARIA',
#     'consejeria': 'AGRICULTURA Y PESCA',
#     'title': 'ORDEN AGR/85/2025, de 27 de enero, por la que se regulan las actividades de formación en materia de bienestar, bioseguridad, higiene y sanidad animal en la Comunidad de Castilla y León.',
#     'heading_level': 3,
#     'heading_hierarchy': 'Introduction | Artículo 21. Notificación electrónica. | DISPOSICIÓN DEROGATORIA. | DISPOSICIÓN DEROGATORIA.',
#     'parent_heading': 'DISPOSICIÓN DEROGATORIA.',
#     'chunk_id': 43,
#     'chunk_total': 59,
#     'heading': 'DISPOSICIÓN DEROGATORIA.'},
#    {'doc_id': 'BOCYL-D-10022025-2',
#     'date': '2025-02-10',
#     'doc_number': 2,
#     'source': 'BOCYL',
#     'type': 'official_document',
#     'area': 'AGRARIA',
#     'consejeria': 'AGRICULTURA Y PESCA',
#     'title': 'ORDEN AGR/85/2025, de 27 de enero, por la que se regulan las actividades de formación en materia de bienestar, bioseguridad, higiene y sanidad animal en la Comunidad de Castilla y León.',
#     'heading_level': 3,
#     'heading_hierarchy': 'Introduction | Artículo 21. Notificación electrónica. | DISPOSICIONES FINALES | DISPOSICIONES FINALES',
#     'parent_heading': 'DISPOSICIONES FINALES',
#     'chunk_id': 44,
#     'chunk_total': 59,
#     'heading': 'DISPOSICIONES FINALES'},
#    {'doc_id': 'BOCYL-D-10022025-2',
#     'date': '2025-02-10',
#     'doc_number': 2,
#     'source': 'BOCYL',
#     'type': 'official_document',
#     'area': 'AGRARIA',
#     'consejeria': 'AGRICULTURA Y PESCA',
#     'title': 'ORDEN AGR/85/2025, de 27 de enero, por la que se regulan las actividades de formación en materia de bienestar, bioseguridad, higiene y sanidad animal en la Comunidad de Castilla y León.',
#     'heading_level': 3,
#     'heading_hierarchy': 'Introduction | Artículo 21. Notificación electrónica. | ANEXO I | ANEXO I',
#     'parent_heading': 'ANEXO I',
#     'subsection': 'Part 1/7',
#     'chunk_id': 45,
#     'chunk_total': 59,
#     'heading': 'ANEXO I'},
#    {'doc_id': 'BOCYL-D-10022025-2',
#     'date': '2025-02-10',
#     'doc_number': 2,
#     'source': 'BOCYL',
#     'type': 'official_document',
#     'area': 'AGRARIA',
#     'consejeria': 'AGRICULTURA Y PESCA',
#     'title': 'ORDEN AGR/85/2025, de 27 de enero, por la que se regulan las actividades de formación en materia de bienestar, bioseguridad, higiene y sanidad animal en la Comunidad de Castilla y León.',
#     'heading_level': 3,
#     'heading_hierarchy': 'Introduction | Artículo 21. Notificación electrónica. | ANEXO I | ANEXO I',
#     'parent_heading': 'ANEXO I',
#     'subsection': 'Part 2/7',
#     'chunk_id': 46,
#     'chunk_total': 59,
#     'heading': 'ANEXO I'},
#    {'doc_id': 'BOCYL-D-10022025-2',
#     'date': '2025-02-10',
#     'doc_number': 2,
#     'source': 'BOCYL',
#     'type': 'official_document',
#     'area': 'AGRARIA',
#     'consejeria': 'AGRICULTURA Y PESCA',
#     'title': 'ORDEN AGR/85/2025, de 27 de enero, por la que se regulan las actividades de formación en materia de bienestar, bioseguridad, higiene y sanidad animal en la Comunidad de Castilla y León.',
#     'heading_level': 3,
#     'heading_hierarchy': 'Introduction | Artículo 21. Notificación electrónica. | ANEXO I | ANEXO I',
#     'parent_heading': 'ANEXO I',
#     'subsection': 'Part 3/7',
#     'chunk_id': 47,
#     'chunk_total': 59,
#     'heading': 'ANEXO I'},
#    {'doc_id': 'BOCYL-D-10022025-2',
#     'date': '2025-02-10',
#     'doc_number': 2,
#     'source': 'BOCYL',
#     'type': 'official_document',
#     'area': 'AGRARIA',
#     'consejeria': 'AGRICULTURA Y PESCA',
#     'title': 'ORDEN AGR/85/2025, de 27 de enero, por la que se regulan las actividades de formación en materia de bienestar, bioseguridad, higiene y sanidad animal en la Comunidad de Castilla y León.',
#     'heading_level': 3,
#     'heading_hierarchy': 'Introduction | Artículo 21. Notificación electrónica. | ANEXO I | ANEXO I',
#     'parent_heading': 'ANEXO I',
#     'subsection': 'Part 4/7',
#     'chunk_id': 48,
#     'chunk_total': 59,
#     'heading': 'ANEXO I'},
#    {'doc_id': 'BOCYL-D-10022025-2',
#     'date': '2025-02-10',
#     'doc_number': 2,
#     'source': 'BOCYL',
#     'type': 'official_document',
#     'area': 'AGRARIA',
#     'consejeria': 'AGRICULTURA Y PESCA',
#     'title': 'ORDEN AGR/85/2025, de 27 de enero, por la que se regulan las actividades de formación en materia de bienestar, bioseguridad, higiene y sanidad animal en la Comunidad de Castilla y León.',
#     'heading_level': 3,
#     'heading_hierarchy': 'Introduction | Artículo 21. Notificación electrónica. | ANEXO I | ANEXO I',
#     'parent_heading': 'ANEXO I',
#     'subsection': 'Part 5/7',
#     'chunk_id': 49,
#     'chunk_total': 59,
#     'heading': 'ANEXO I'},
#    {'doc_id': 'BOCYL-D-10022025-2',
#     'date': '2025-02-10',
#     'doc_number': 2,
#     'source': 'BOCYL',
#     'type': 'official_document',
#     'area': 'AGRARIA',
#     'consejeria': 'AGRICULTURA Y PESCA',
#     'title': 'ORDEN AGR/85/2025, de 27 de enero, por la que se regulan las actividades de formación en materia de bienestar, bioseguridad, higiene y sanidad animal en la Comunidad de Castilla y León.',
#     'heading_level': 3,
#     'heading_hierarchy': 'Introduction | Artículo 21. Notificación electrónica. | ANEXO I | ANEXO I',
#     'parent_heading': 'ANEXO I',
#     'subsection': 'Part 6/7',
#     'chunk_id': 50,
#     'chunk_total': 59,
#     'heading': 'ANEXO I'},
#    {'doc_id': 'BOCYL-D-10022025-2',
#     'date': '2025-02-10',
#     'doc_number': 2,
#     'source': 'BOCYL',
#     'type': 'official_document',
#     'area': 'AGRARIA',
#     'consejeria': 'AGRICULTURA Y PESCA',
#     'title': 'ORDEN AGR/85/2025, de 27 de enero, por la que se regulan las actividades de formación en materia de bienestar, bioseguridad, higiene y sanidad animal en la Comunidad de Castilla y León.',
#     'heading_level': 3,
#     'heading_hierarchy': 'Introduction | Artículo 21. Notificación electrónica. | ANEXO I | ANEXO I',
#     'parent_heading': 'ANEXO I',
#     'subsection': 'Part 7/7',
#     'chunk_id': 51,
#     'chunk_total': 59,
#     'heading': 'ANEXO I'},
#    {'doc_id': 'BOCYL-D-10022025-2',
#     'date': '2025-02-10',
#     'doc_number': 2,
#     'source': 'BOCYL',
#     'type': 'official_document',
#     'area': 'AGRARIA',
#     'consejeria': 'AGRICULTURA Y PESCA',
#     'title': 'ORDEN AGR/85/2025, de 27 de enero, por la que se regulan las actividades de formación en materia de bienestar, bioseguridad, higiene y sanidad animal en la Comunidad de Castilla y León.',
#     'heading_level': 3,
#     'heading_hierarchy': 'Introduction | Artículo 21. Notificación electrónica. | ANEXO II | ANEXO II',
#     'parent_heading': 'ANEXO II',
#     'chunk_id': 52,
#     'chunk_total': 59,
#     'heading': 'ANEXO II'},
#    {'doc_id': 'BOCYL-D-10022025-2',
#     'date': '2025-02-10',
#     'doc_number': 2,
#     'source': 'BOCYL',
#     'type': 'official_document',
#     'area': 'AGRARIA',
#     'consejeria': 'AGRICULTURA Y PESCA',
#     'title': 'ORDEN AGR/85/2025, de 27 de enero, por la que se regulan las actividades de formación en materia de bienestar, bioseguridad, higiene y sanidad animal en la Comunidad de Castilla y León.',
#     'heading_level': 3,
#     'heading_hierarchy': 'Introduction | Artículo 21. Notificación electrónica. | PROGRAMA DEL CURSO DE BIENESTAR ANIMAL EN EL TRANSPORTE | PROGRAMA DEL CURSO DE BIENESTAR ANIMAL EN EL TRANSPORTE',
#     'parent_heading': 'PROGRAMA DEL CURSO DE BIENESTAR ANIMAL EN EL TRANSPORTE',
#     'subsection': 'Part 1/2',
#     'chunk_id': 53,
#     'chunk_total': 59,
#     'heading': 'PROGRAMA DEL CURSO DE BIENESTAR ANIMAL EN EL TRANSPORTE'},
#    {'doc_id': 'BOCYL-D-10022025-2',
#     'date': '2025-02-10',
#     'doc_number': 2,
#     'source': 'BOCYL',
#     'type': 'official_document',
#     'area': 'AGRARIA',
#     'consejeria': 'AGRICULTURA Y PESCA',
#     'title': 'ORDEN AGR/85/2025, de 27 de enero, por la que se regulan las actividades de formación en materia de bienestar, bioseguridad, higiene y sanidad animal en la Comunidad de Castilla y León.',
#     'heading_level': 3,
#     'heading_hierarchy': 'Introduction | Artículo 21. Notificación electrónica. | PROGRAMA DEL CURSO DE BIENESTAR ANIMAL EN EL TRANSPORTE | PROGRAMA DEL CURSO DE BIENESTAR ANIMAL EN EL TRANSPORTE',
#     'parent_heading': 'PROGRAMA DEL CURSO DE BIENESTAR ANIMAL EN EL TRANSPORTE',
#     'subsection': 'Part 2/2',
#     'chunk_id': 54,
#     'chunk_total': 59,
#     'heading': 'PROGRAMA DEL CURSO DE BIENESTAR ANIMAL EN EL TRANSPORTE'},
#    {'doc_id': 'BOCYL-D-10022025-2',
#     'date': '2025-02-10',
#     'doc_number': 2,
#     'source': 'BOCYL',
#     'type': 'official_document',
#     'area': 'AGRARIA',
#     'consejeria': 'AGRICULTURA Y PESCA',
#     'title': 'ORDEN AGR/85/2025, de 27 de enero, por la que se regulan las actividades de formación en materia de bienestar, bioseguridad, higiene y sanidad animal en la Comunidad de Castilla y León.',
#     'heading_level': 3,
#     'heading_hierarchy': 'Introduction | Artículo 21. Notificación electrónica. | ANEXO III | ANEXO III',
#     'parent_heading': 'ANEXO III',
#     'subsection': 'Part 1/2',
#     'chunk_id': 55,
#     'chunk_total': 59,
#     'heading': 'ANEXO III'},
#    {'doc_id': 'BOCYL-D-10022025-2',
#     'date': '2025-02-10',
#     'doc_number': 2,
#     'source': 'BOCYL',
#     'type': 'official_document',
#     'area': 'AGRARIA',
#     'consejeria': 'AGRICULTURA Y PESCA',
#     'title': 'ORDEN AGR/85/2025, de 27 de enero, por la que se regulan las actividades de formación en materia de bienestar, bioseguridad, higiene y sanidad animal en la Comunidad de Castilla y León.',
#     'heading_level': 3,
#     'heading_hierarchy': 'Introduction | Artículo 21. Notificación electrónica. | ANEXO III | ANEXO III',
#     'parent_heading': 'ANEXO III',
#     'subsection': 'Part 2/2',
#     'chunk_id': 56,
#     'chunk_total': 59,
#     'heading': 'ANEXO III'},
#    {'doc_id': 'BOCYL-D-10022025-2',
#     'date': '2025-02-10',
#     'doc_number': 2,
#     'source': 'BOCYL',
#     'type': 'official_document',
#     'area': 'AGRARIA',
#     'consejeria': 'AGRICULTURA Y PESCA',
#     'title': 'ORDEN AGR/85/2025, de 27 de enero, por la que se regulan las actividades de formación en materia de bienestar, bioseguridad, higiene y sanidad animal en la Comunidad de Castilla y León.',
#     'heading_level': 3,
#     'heading_hierarchy': 'Introduction | Artículo 21. Notificación electrónica. | ANEXO IV | ANEXO IV',
#     'parent_heading': 'ANEXO IV',
#     'chunk_id': 57,
#     'chunk_total': 59,
#     'heading': 'ANEXO IV'},
#    {'doc_id': 'BOCYL-D-10022025-2',
#     'date': '2025-02-10',
#     'doc_number': 2,
#     'source': 'BOCYL',
#     'type': 'official_document',
#     'area': 'AGRARIA',
#     'consejeria': 'AGRICULTURA Y PESCA',
#     'title': 'ORDEN AGR/85/2025, de 27 de enero, por la que se regulan las actividades de formación en materia de bienestar, bioseguridad, higiene y sanidad animal en la Comunidad de Castilla y León.',
#     'heading_level': 3,
#     'heading_hierarchy': 'Introduction | Artículo 21. Notificación electrónica. | ANEXO V | ANEXO V',
#     'parent_heading': 'ANEXO V',
#     'chunk_id': 58,
#     'chunk_total': 59,
#     'heading': 'ANEXO V'}]}]

# %% [markdown]
# ### Vectordb as retriever

# %%
retriever = vectordb.as_retriever(
    search_type="similarity",
    search_kwargs={"k": 4}
)

# %% [markdown]
# ### Template for the context

# %%
template = """Answer the question based only on the following context:

{context}

Question: {question}

Answer in Spanish. If the answer cannot be found in the context, say "No encuentro información sobre esto en los documentos proporcionados."
"""

# %%
from langchain.prompts import ChatPromptTemplate
prompt = ChatPromptTemplate.from_template(template)

prompt
# Out:
# ChatPromptTemplate(input_variables=['context', 'question'], input_types={}, partial_variables={}, messages=[HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['context', 'question'], input_types={}, partial_variables={}, template='Answer the question based only on the following context:\n\n{context}\n\nQuestion: {question}\n\nAnswer in Spanish. If the answer cannot be found in the context, say "No encuentro información sobre esto en los documentos proporcionados."\n'), additional_kwargs={})])

# %% [markdown]
# ### Instantiate LLM

# %%
from langchain_openai import ChatOpenAI
llm = ChatOpenAI(model="chatgpt-4o-latest")

# %% [markdown]
# ### Compose RAG Chain

# %%
from langchain.schema.runnable import RunnablePassthrough
from langchain.schema.output_parser import StrOutputParser

def format_docs(docs):
    return "\n\n".join([doc.page_content for doc in docs])

rag_chain = (
    {"context": retriever | format_docs, "question": RunnablePassthrough()}
    | prompt
    | llm
    | StrOutputParser()
)

# %% [markdown]
# ## Test the RAG Chain

# %% [markdown]
# ### [X] Query

# %%
query = "Ultima normativa agraria publicada en BOCYL, dame un resumen con lo mas importante."

# %%
response = rag_chain.invoke(query)
print(response)
# Out:
# La última normativa agraria publicada en el Boletín Oficial de Castilla y León (BOCYL) mencionada en el contexto se refiere a una orden que deroga la Orden AYG/565/2004, de 13 de abril, y regula de manera unificada:
#
# - La formación sobre bienestar animal.
# - La formación en bioseguridad, higiene y sanidad animal para operadores y profesionales que trabajan con animales de producción.
# - El procedimiento de registro de las entidades de formación.
# - La comunicación de las distintas ediciones de los cursos.
# - La obtención de certificados de competencia en las materias mencionadas.
#
# Esta nueva normativa responde a la experiencia adquirida con la anterior regulación, y a la creciente sensibilidad social por la protección animal, el respeto al medio ambiente y la salud pública.
#
# Además, establece que las entidades y personas formadoras, debido a su cualificación técnica y acceso a medios electrónicos, deben comunicarse electrónicamente con la administración y recibir notificaciones en ese formato, en cumplimiento de la Ley 39/2015, de 1 de octubre.
#
# Resumen: Se ha aprobado una nueva regulación que unifica todos los procesos relacionados con formación en bienestar animal y sanidad de animales de producción, imponiendo la tramitación electrónica en todos los procedimientos relacionados.

# %%
vectordb.vectorstore.similarity_search(query, k=4)
# Out:
# [Document(id='BOCYL-D-21032025-2_2', metadata={'area': 'AGRARIA', 'chunk_id': 2, 'chunk_total': 3, 'consejeria': 'AGRICULTURA Y PESCA', 'date': '2025-03-21', 'doc_id': 'BOCYL-D-21032025-2', 'doc_number': 2, 'heading': 'RESUELVE', 'heading_hierarchy': 'Introduction | RESUELVE', 'heading_level': 3, 'parent_heading': 'Introduction', 'source': 'BOCYL', 'subsection': 'Part 2/2', 'title': 'RESOLUCIÓN de 13 de marzo de 2025, de la Secretaria General de la Consejería de Agricultura, Ganadería y Desarrollo Rural, por la que se aprueba y publica la relación definitiva de candidatos de la bolsa de empleo temporal del Cuerpo de Ayudantes Facultativos (Inspectores de Campo) de la Administración de la Comunidad de Castilla y León, convocada por Orden PRE/556/2024, de 7 de junio.', 'type': 'official_document'}, page_content='Cuarto.  La relación definitiva de candidatos de esta bolsa de empleo temporal del Cuerpo de Ayudantes Facultativos (Inspectores de Campo) de la Administración de la Comunidad de Castilla y León se pondrá en funcionamiento el primer día hábil siguiente a la publicación de la presente resolución en el Boletín Oficial de Castilla y León.\n\nQuinto.  Contra la presente resolución, que agota la vía administrativa, los interesados podrán interponer recurso contencioso-administrativo ante el Juzgado de lo Contencioso-Administrativo de Valladolid, en el plazo de dos meses contados desde el día siguiente a su publicación en el Boletín Oficial de Castilla y León, de conformidad con lo establecido en los artículos 8.2 y 14.2 de la Ley 29/1998, de 13 de julio, Reguladora de la Jurisdicción Contencioso-Administrativa.\n\nIgualmente, con carácter previo, podrá interponerse recurso de reposición ante la Dirección General de Función Pública, en el plazo de un mes a contar desde el día siguiente a su publicación, de conformidad con los artículos 123 y 124 de la Ley 39/2015, de 1 de octubre, del Procedimiento Administrativo Común de las Administraciones Públicas, no pudiéndose en este caso interponer recurso contencioso-administrativo hasta que sea resuelto expresamente o se haya producido la desestimación presunta del recurso de reposición interpuesto.'),
#  Document(id='BOCYL-D-26022025-18_1', metadata={'area': 'AGRARIA', 'chunk_id': 1, 'chunk_total': 3, 'consejeria': 'AGRICULTURA Y PESCA', 'date': '2025-02-26', 'doc_id': 'BOCYL-D-26022025-18', 'doc_number': 18, 'heading': 'ANUNCIO del Servicio Territorial de Agricultura, Ganadería y Desarrollo Rural de León, relativo a la apertura del trámite de información pública de la aprobación de las bases provisionales de la concentración parcelaria de la zona de Almanza II (León).', 'heading_hierarchy': 'ANUNCIO del Servicio Territorial de Agricultura, Ganadería y Desarrollo Rural de León, relativo a la apertura del trámite de información pública de la aprobación de las bases provisionales de la concentración parcelaria de la zona de Almanza II (León).', 'heading_level': 1, 'parent_heading': 'None', 'source': 'BOCYL', 'subsection': 'Part 2/3', 'title': 'ANUNCIO del Servicio Territorial de Agricultura, Ganadería y Desarrollo Rural de León, relativo a la apertura del trámite de información pública de la aprobación de las bases provisionales de la concentración parcelaria de la zona de Almanza II (León).', 'type': 'official_document'}, page_content='A través de una asamblea informativa sobre los trabajos realizados y su continuación, que tendrá lugar en el local habilitado al efecto por el Ayuntamiento de Almanza (León), y cuya convocatoria se realizará con la debida antelación a dicho Ayuntamiento, los técnicos partícipes en la elaboración de las Bases Provisionales facilitarán el calendario de días en los que estarán a disposición de los interesados para aclarar dudas que se pudieran plantear, de conformidad con lo previsto en el artículo 20.5 del Decreto 1/2018, de 11 de enero, así como para entregar los Boletines Individuales de la Propiedad (documento T-5).\n\nSe advierte especialmente a los cultivadores de fincas (arrendatarios, aparceros, usufructuarios, etc.) y a los titulares de hipotecas o cualquier derecho sobre las mismas, que deben asimismo, dentro del plazo señalado, comprobar si su derecho ha sido reconocido por el propietario en el Boletín Individual de la Propiedad, ya que en dicho impreso deberá figurar su nombre o la finca que cultiva o se halle gravada a su favor.\n\nSe emplaza a todos los propietarios, en especial a los que tengan su derecho inscrito en el Registro de la Propiedad o a las personas que traigan causa del mismo para que, si aprecian contradicciones entre el contenido de los asientos del Registro que les afecten y la atribución de propiedad u otros derechos provisionalmente realizada como consecuencia de la investigación, puedan formular oposición aportando certificación registral de los asientos contradictorios y, en su caso, los documentos que acrediten al contradictor como causahabiente de los titulares inscritos, apercibiéndoles de que, si no lo hicieran, se declarará el dominio de las parcelas y sus gravámenes o situaciones jurídicas en la forma en que se publica al efecto de su inscripción en el Registro de la Propiedad.'),
#  Document(id='BOCYL-D-02042025-23_142', metadata={'area': 'AGRARIA', 'chunk_id': 142, 'chunk_total': 476, 'consejeria': 'AGRICULTURA Y PESCA', 'date': '2025-04-02', 'doc_id': 'BOCYL-D-02042025-23', 'doc_number': 23, 'heading': 'B', 'heading_hierarchy': 'Introduction | B | B', 'heading_level': 3, 'parent_heading': 'B', 'source': 'BOCYL', 'title': 'RESOLUCIÓN de 19 de marzo de 2025, de la Dirección General de Política Agraria Comunitaria, por la que se establece la clasificación de los criterios de evaluación de gravedad, alcance y persistencia, y el cálculo de las reducciones a los efectos de aplicar la condicionalidad reforzada y social de las ayudas de la Política Agrícola Común, en el año 2024.', 'type': 'official_document'}, page_content='VALORACIÓN DE LOS ÁMBITOS DE LA SALUD PÚBLICA Y LA FITOSANIDAD Y DEL BIENESTAR ANIMAL.\n\nRLG 5. Reglamento (CE) n.º 178/2002 del Parlamento Europeo y del Consejo, de 28 de enero de 2022, por la que se establecen los principios y los requisitos generales de la legislación alimentaria, se crea la Autoridad Europea de Seguridad Alimentaria y se fijan procedimientos relativos a la seguridad alimentaria (DO L 31 de 1.2.2002, p.1).'),
#  Document(id='BOCYL-D-10022025-2_4', metadata={'area': 'AGRARIA', 'chunk_id': 4, 'chunk_total': 59, 'consejeria': 'AGRICULTURA Y PESCA', 'date': '2025-02-10', 'doc_id': 'BOCYL-D-10022025-2', 'doc_number': 2, 'heading': 'ORDEN AGR/85/2025, de 27 de enero, por la que se regulan las actividades de formación en materia de bienestar, bioseguridad, higiene y sanidad animal en la Comunidad de Castilla y León.', 'heading_hierarchy': 'ORDEN AGR/85/2025, de 27 de enero, por la que se regulan las actividades de formación en materia de bienestar, bioseguridad, higiene y sanidad animal en la Comunidad de Castilla y León.', 'heading_level': 1, 'parent_heading': 'None', 'source': 'BOCYL', 'subsection': 'Part 5/8', 'title': 'ORDEN AGR/85/2025, de 27 de enero, por la que se regulan las actividades de formación en materia de bienestar, bioseguridad, higiene y sanidad animal en la Comunidad de Castilla y León.', 'type': 'official_document'}, page_content='En Castilla y León, hasta el momento, las actividades formativas en materia de bienestar animal están reguladas por la Orden AYG/565/2004, de 13 de abril, por la que se establecen las normas para la homologación de cursos de formación y para la expedición de certificado acreditativo en materia de bienestar animal, que se deroga con la presente orden.\n\nNo obstante, tras el tiempo transcurrido y la experiencia adquirida con la citada regulación autonómica, así como la necesidad de dar respuesta a la creciente sensibilidad de la sociedad en torno al respeto medioambiental, a la protección y la defensa de los animales y la creciente preocupación por la salud pública, se hace preciso concentrar en una sola norma tanto la formación sobre bienestar animal como la formación en materia de bioseguridad, higiene y sanidad animal de los operadores y profesionales que trabajen con animales de producción, así como el procedimiento de registro de las entidades de formación, el procedimiento de comunicación de las distintas ediciones de cursos, y el procedimiento para la obtención de los certificados de competencia en las citadas materias.\n\nPor otra parte, por aplicación del artículo 14, apartados 2 y 3 y artículo 41.1 párrafo cuarto de la Ley 39/2015, de 1 de octubre, del Procedimiento Administrativo Común de las Administraciones Públicas, tanto las entidades de formación como las personas físicas que realizan actividades de formación, dada la cualificación técnica de estas, y su acceso y disponibilidad de medios electrónicos, tendrán la obligación de relacionarse electrónicamente con la administración en los procedimientos establecidos en esta orden así como a la recepción electrónica de las notificaciones.')]

# %% [markdown]
# ### Save outputs

# %%
import datetime
import hashlib

current_datetime = datetime.datetime.now().strftime("%Y%m%d_%H%M%S")

response_hash = hashlib.md5(response.encode()).hexdigest()

filename = f"outputs/{current_datetime}_{response_hash}.md"

with open(filename, 'w') as f:
    f.write(response)
